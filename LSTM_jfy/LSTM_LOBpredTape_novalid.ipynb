# %%
import os
import pandas as pd
import numpy as np
import shutil
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.models import load_model
# Out:
# 2024-04-29 00:49:30.582081: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-29 00:49:30.724209: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-29 00:49:31.745475: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-29 00:49:31.748497: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-29 00:49:32.881498: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# 数据加载函数
def load_and_process_data(lob_path, tape_path):
    # Load LOB data
    Feature_UoB_Set01_LOBs = pd.read_csv(lob_path).dropna()
    Feature_UoB_Set01_LOBs = Feature_UoB_Set01_LOBs.reset_index().drop("index", axis=1)
    
    # Load Tape data
    clean_uob_set01_tapes = pd.read_csv(tape_path)
    
    # Resample and adjust function
    def resample_and_adjust_using_original_times(df, target_count):
        # Assuming 'Time' is in seconds and 'Weighted_Price' is the price
        df['Time_bin'] = (df['Time'] // 10 * 10).astype(int)
        
        # Ensure the range includes 0-10 seconds bin
        all_time_bins = range(0, df['Time_bin'].max() + 10, 10)  # Starts from 0 now
        grouped = df.groupby('Time_bin')
        
        new_records = []
        last_known_price = df['Weighted_Price'].iloc[0]  # Initialize with the first known price
        
        # Iterate through all possible time bins
        for time_bin in all_time_bins:
            if time_bin in grouped.groups:
                group = grouped.get_group(time_bin)
                times = group['Time'].values
                prices = group['Weighted_Price'].values
                if len(prices) > 0:
                    last_known_price = prices[-1]
            else:
                group = None
            
            # If the current time bin is empty or has only one price data point
            if group is None or len(prices) == 0:
                prices = np.full(target_count, last_known_price)
                times = np.linspace(time_bin, time_bin + 9, num=target_count)
            elif len(prices) == 1:
                times = np.linspace(time_bin, time_bin + 9, num=target_count)
                prices = np.full(target_count, last_known_price)
            else:
                # If there are fewer data points than the target count, additional points will be added
                while len(prices) < target_count:
                    time_diffs = np.diff(times)
                    idx_to_fill = np.argmax(time_diffs)
                    new_time = (times[idx_to_fill] + times[idx_to_fill + 1]) / 2
                    new_price = (prices[idx_to_fill] + prices[idx_to_fill + 1]) / 2
                    times = np.insert(times, idx_to_fill + 1, new_time)
                    prices = np.insert(prices, idx_to_fill + 1, new_price)
                # If there are multiple data points within the time bin, proceed with normal processing
                while len(prices) > target_count:
                    time_diffs = np.diff(times)
                    idx_to_merge = np.argmin(time_diffs)
                    new_time = (times[idx_to_merge] + times[idx_to_merge + 1]) / 2
                    new_price = (prices[idx_to_merge] + prices[idx_to_merge + 1]) / 2
                    times = np.delete(times, [idx_to_merge, idx_to_merge + 1])
                    times = np.insert(times, idx_to_merge, new_time)
                    prices = np.delete(prices, [idx_to_merge, idx_to_merge + 1])
                    prices = np.insert(prices, idx_to_merge, new_price)
            # Add the processed data to the results list          
            new_records.extend(zip(times, prices))
    
        new_df = pd.DataFrame(new_records, columns=['Time', 'Weighted_Price'])
        new_df.sort_values('Time', inplace=True)
        return new_df


    # Resample the data
    processed_df = resample_and_adjust_using_original_times(clean_uob_set01_tapes, 6)
    
    
    # Create dataset function
    def create_dataset(data, time_step, step=6):
        X, y = [], []
        for i in range(0, len(data)-time_step, step):
            X.append(data[i:(i+time_step), 0])
            y.append(data[(i+time_step):(i+time_step+6), 0])
        return np.array(X), np.array(y)

    price = processed_df['Weighted_Price'].values.reshape(-1, 1)
    time_step = 360
    _, tags = create_dataset(price, time_step, step=6)

    # 重点重点！！！！！！！！！！Feature scaling不能放在循环里！
    #scaler = MinMaxScaler()
    #features = scaler.fit_transform(Feature_UoB_Set01_LOBs)
    #targets = scaler.fit_transform(tags)
    features = Feature_UoB_Set01_LOBs
    targets = tags

    np.save(lob_path[-18:-4]+'_features.npy', features)
    np.save(tape_path[-19:-4]+'_targets.npy', targets)
    
    return features, targets

# %%
def preprocess(directory0, directory1):
    files_lob = os.listdir(directory0)
    files_tape = os.listdir(directory1)
    
    for file_lob, file_tape in zip(files_lob, files_tape):
        file_path0 = os.path.join(directory0, file_lob)
        file_path1 = os.path.join(directory1, file_tape)
        print("Processing: ", file_path0, " and ", file_path1)
        load_and_process_data(file_path0, file_path1)

# %%
def move_files(source_dir, lobs_dir, tapes_dir):
    if not os.path.exists(lobs_dir):
        os.makedirs(lobs_dir)
    if not os.path.exists(tapes_dir):
        os.makedirs(tapes_dir)

    # 遍历源目录中的所有文件
    for file in os.listdir(source_dir):
        full_file_path = os.path.join(source_dir, file)
        if os.path.isfile(full_file_path):
            if file.endswith("features.npy"):
                # 移动文件到lobs_dir
                shutil.move(full_file_path, os.path.join(lobs_dir, file))
                print(f"Moved {file} to {lobs_dir}")
            elif file.endswith("targets.npy"):
                # 移动文件到tapes_dir
                shutil.move(full_file_path, os.path.join(tapes_dir, file))
                print(f"Moved {file} to {tapes_dir}")
            else:
                print(f"Skipped {file}, did not match criteria.")
        else:
            print(f"Skipping directory: {file}")

# %%
# train数据集预处理
preprocess("data/train/lobs", "data/train/tapes")


source_directory = "/home/ec2-user/LSTM_LOBpredTape"
train_lob_dir = "/home/ec2-user/LSTM_LOBpredTape/train/lobs"
train_tape_dir = "/home/ec2-user/LSTM_LOBpredTape/train/tapes"

# 移动文件
move_files(source_directory, train_lob_dir, train_tape_dir)
# Out:
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-02LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-02tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-03LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-03tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-06LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-06tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-07LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-07tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-08LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-08tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-09LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-09tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-10LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-10tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-13LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-13tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-14LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-14tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-15LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-15tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-16LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-16tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-17LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-17tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-20LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-20tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-21LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-21tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-22LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-22tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-23LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-23tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-24LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-24tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-27LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-27tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-28LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-28tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-29LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-29tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-30LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-30tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-01-31LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-01-31tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-03LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-03tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-04LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-04tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-05LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-05tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-06LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-06tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-07LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-07tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-10LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-10tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-11LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-11tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-12LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-12tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-13LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-13tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-14LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-14tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-17LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-17tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-18LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-18tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-19LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-19tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-20LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-20tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-21LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-21tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-24LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-24tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-25LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-25tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-26LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-26tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-27LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-27tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-02-28LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-02-28tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-03LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-03tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-04LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-04tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-05LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-05tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-06LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-06tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-07LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-07tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-10LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-10tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-11LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-11tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-12LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-12tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-13LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-13tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-14LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-14tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-17LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-17tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-18LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-18tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-19LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-19tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-20LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-20tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-21LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-21tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-24LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-24tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-25LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-25tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-26LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-26tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-27LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-27tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-28LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-28tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-03-31LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-03-31tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-01LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-01tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-02LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-02tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-03LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-03tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-04LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-04tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-07LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-07tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-08LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-08tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-09LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-09tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-10LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-10tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-11LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-11tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-14LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-14tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-15LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-15tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-16LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-16tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-17LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-17tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-22LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-22tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-23LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-23tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-24LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-24tapes.csv
# Processing:  data/train/lobs/Featured_Clean_UoB_Set01_2025-04-25LOBs.txt  and  data/train/tapes/Clean_UoB_Set01_2025-04-25tapes.csv
# Skipped LSTM_LOBpredTape_2.ipynb, did not match criteria.
# Skipping directory: .ipynb_checkpoints
# Skipping directory: data
# Moved 2025-01-03LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-03tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-06LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-06tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-07LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-07tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-08LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-08tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-09LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-09tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-10LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-10tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-13LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-13tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-14LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-14tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-15LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-15tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-16LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-16tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-17LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-17tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-20LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-20tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-21tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-22LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-23LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-24LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-24tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-27tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-28tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-29LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-30LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-31LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-31tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-03tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-04tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-05LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-06LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-07LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-07tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-10tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-11tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-12LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-13LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-14LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-14tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-17tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-18tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-19LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-20LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-21LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-21tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-24tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-25tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-26LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-27LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-28LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-28tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-03tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-04tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-05LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-06LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-07LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-07tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-10tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-11tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-12LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-13LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-14LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-14tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-17tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-18tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-19LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-20LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-21LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-21tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-24tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-25tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-26LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-27LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-28LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-28tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-31tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-01tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-02LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-03LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-04LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-04tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-07tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-08tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-09LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-10LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-11LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-11tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-14tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-15tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-16LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-17LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-22LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-22tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-23tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-24tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-25LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Skipping directory: train
# Skipping directory: checkpoints
# Skipped checkpoints.tar.gz, did not match criteria.
# Moved 2025-01-02LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-02tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-21LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-22tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-23tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-27LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-28LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-01-29tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-01-30tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-03LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-04LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-05tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-06tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-10LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-11LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-12tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-13tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-17LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-18LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-19tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-20tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-24LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-25LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-02-26tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-02-27tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-03LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-04LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-05tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-06tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-10LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-11LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-12tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-13tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-17LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-18LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-19tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-20tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-24LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-25LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-03-26tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-27tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-03-31LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-01LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-02tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-03tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-07LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-08LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-09tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-10tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-14LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-15LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-16tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-17tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes
# Moved 2025-04-23LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-24LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/train/lobs
# Moved 2025-04-25tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/train/tapes

# %%
# validate数据集预处理
preprocess("data/validate/lobs", "data/validate/tapes")

source_directory = "/home/ec2-user/LSTM_LOBpredTape"
validate_lob_dir = "/home/ec2-user/LSTM_LOBpredTape/validate/lobs"
validate_tape_dir = "/home/ec2-user/LSTM_LOBpredTape/validate/tapes"

# 移动文件
move_files(source_directory, validate_lob_dir, validate_tape_dir)
# Out:
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-04-28LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-04-28tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-04-29LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-04-29tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-04-30LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-04-30tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-01LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-01tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-02LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-02tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-06LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-06tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-07LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-07tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-08LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-08tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-09LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-09tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-12LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-12tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-13LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-13tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-14LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-14tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-15LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-15tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-16LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-16tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-19LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-19tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-20LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-20tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-21LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-21tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-22LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-22tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-23LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-23tapes.csv
# Processing:  data/validate/lobs/Featured_Clean_UoB_Set01_2025-05-27LOBs.txt  and  data/validate/tapes/Clean_UoB_Set01_2025-05-27tapes.csv
# Skipped LSTM_LOBpredTape_2.ipynb, did not match criteria.
# Skipping directory: .ipynb_checkpoints
# Skipping directory: data
# Skipping directory: train
# Skipping directory: checkpoints
# Skipped checkpoints.tar.gz, did not match criteria.
# Moved 2025-04-28LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-04-28tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-04-29LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-04-29tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-04-30LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-04-30tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-01LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-01tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-02LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-02tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-06LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-06tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-07LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-07tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-08LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-08tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-09LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-09tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-12LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-12tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-13LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-13tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-14LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-14tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-15LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-15tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-16LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-16tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-19LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-19tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-20LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-20tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-21LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-21tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-22LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-22tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-23LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-23tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Moved 2025-05-27LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/validate/lobs
# Moved 2025-05-27tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/validate/tapes
# Skipping directory: validate

# %%
# test数据集预处理
preprocess("data/test/lobs", "data/test/tapes")


source_directory = "/home/ec2-user/LSTM_LOBpredTape"
test_lob_dir = "/home/ec2-user/LSTM_LOBpredTape/test/lobs"
test_tape_dir = "/home/ec2-user/LSTM_LOBpredTape/test/tapes"

# 移动文件
move_files(source_directory, test_lob_dir, test_tape_dir)
# Out:
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-05-28LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-05-28tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-05-29LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-05-29tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-05-30LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-05-30tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-02LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-02tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-03LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-03tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-04LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-04tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-05LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-05tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-06LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-06tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-09LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-09tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-10LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-10tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-11LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-11tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-12LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-12tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-13LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-13tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-16LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-16tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-17LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-17tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-18LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-18tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-19LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-19tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-20LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-20tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-23LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-23tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-24LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-24tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-25LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-25tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-26LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-26tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-27LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-27tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-06-30LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-06-30tapes.csv
# Processing:  data/test/lobs/Featured_Clean_UoB_Set01_2025-07-01LOBs.txt  and  data/test/tapes/Clean_UoB_Set01_2025-07-01tapes.csv
# Skipped LSTM_LOBpredTape_2.ipynb, did not match criteria.
# Skipping directory: .ipynb_checkpoints
# Skipping directory: data
# Moved 2025-06-25LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-26LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-27tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-30tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Skipping directory: test
# Skipping directory: train
# Moved 2025-06-25tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-26tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-30LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-07-01LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Skipping directory: checkpoints
# Skipped checkpoints.tar.gz, did not match criteria.
# Skipping directory: validate
# Moved 2025-05-28LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-05-28tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-05-29LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-05-29tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-05-30LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-05-30tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-02LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-02tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-03LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-03tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-04LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-04tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-05LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-05tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-06LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-06tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-09LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-09tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-10LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-10tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-11LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-11tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-12LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-12tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-13LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-13tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-16LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-16tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-17LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-17tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-18LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-18tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-19LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-19tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-20LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-20tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-23LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-23tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-24LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-06-24tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes
# Moved 2025-06-27LOBs_features.npy to /home/ec2-user/LSTM_LOBpredTape/test/lobs
# Moved 2025-07-01tapes_targets.npy to /home/ec2-user/LSTM_LOBpredTape/test/tapes

# %%
# train合并成两个大的dataframe

# 指定文件夹的路径
train_LOBs_path = "train/lobs"
train_Tapes_path = "train/tapes"

# 读取文件夹中所有的.npy文件
files_train_LOBs = [f for f in os.listdir(train_LOBs_path) if f.endswith('.npy')]
files_train_Tapes = [f for f in os.listdir(train_Tapes_path) if f.endswith('.npy')]

# 初始化空的DataFrames
train_LOBs_df = pd.DataFrame()
train_Tapes_df = pd.DataFrame()

# 遍历文件列表，加载每个文件并追加到DataFrame
for file in files_train_LOBs:
    # 加载.npy文件
    data = np.load(os.path.join(train_LOBs_path, file))
    # 将numpy数组转换为DataFrame
    temp_LOBs_df = pd.DataFrame(data)
    # 追加到主DataFrame
    train_LOBs_df = pd.concat([train_LOBs_df, temp_LOBs_df], ignore_index=True)

for file in files_train_Tapes:
    # 加载.npy文件
    data = np.load(os.path.join(train_Tapes_path, file))
    # 将numpy数组转换为DataFrame
    temp_Tapes_df = pd.DataFrame(data)
    # 追加到主DataFrame
    train_Tapes_df = pd.concat([train_Tapes_df, temp_Tapes_df], ignore_index=True)

# 保存成文件
train_LOBs_df.to_csv('train_LOBs_df.csv')
train_Tapes_df.to_csv('train_Tapes_df.csv')

# %%
# validate合并成两个大的dataframe

# 指定文件夹的路径
valid_LOBs_path = "validate/lobs"
valid_Tapes_path = "validate/tapes"

# 读取文件夹中所有的.npy文件
files_valid_LOBs = [f for f in os.listdir(valid_LOBs_path) if f.endswith('.npy')]
files_valid_Tapes = [f for f in os.listdir(valid_Tapes_path) if f.endswith('.npy')]

# 初始化空的DataFrames
valid_LOBs_df = pd.DataFrame()
valid_Tapes_df = pd.DataFrame()

# 遍历文件列表，加载每个文件并追加到DataFrame
for file in files_valid_LOBs:
    # 加载.npy文件
    data = np.load(os.path.join(valid_LOBs_path, file))
    # 将numpy数组转换为DataFrame
    temp_LOBs_df = pd.DataFrame(data)
    # 追加到主DataFrame
    valid_LOBs_df = pd.concat([valid_LOBs_df, temp_LOBs_df], ignore_index=True)

for file in files_valid_Tapes:
    # 加载.npy文件
    data = np.load(os.path.join(valid_Tapes_path, file))
    # 将numpy数组转换为DataFrame
    temp_Tapes_df = pd.DataFrame(data)
    # 追加到主DataFrame
    valid_Tapes_df = pd.concat([valid_Tapes_df, temp_Tapes_df], ignore_index=True)

# 保存成文件
valid_LOBs_df.to_csv('valid_LOBs_df.csv')
valid_Tapes_df.to_csv('valid_Tapes_df.csv')

# %%
# test合并成两个大的dataframe

# 指定文件夹的路径
test_LOBs_path = "test/lobs"
test_Tapes_path = "test/tapes"

# 读取文件夹中所有的.npy文件
files_test_LOBs = [f for f in os.listdir(test_LOBs_path) if f.endswith('.npy')]
files_test_Tapes = [f for f in os.listdir(test_Tapes_path) if f.endswith('.npy')]

# 初始化空的DataFrames
test_LOBs_df = pd.DataFrame()
test_Tapes_df = pd.DataFrame()

# 遍历文件列表，加载每个文件并追加到DataFrame
for file in files_test_LOBs:
    # 加载.npy文件
    data = np.load(os.path.join(test_LOBs_path, file))
    # 将numpy数组转换为DataFrame
    temp_LOBs_df = pd.DataFrame(data)
    # 追加到主DataFrame
    test_LOBs_df = pd.concat([test_LOBs_df, temp_LOBs_df], ignore_index=True)

for file in files_test_Tapes:
    # 加载.npy文件
    data = np.load(os.path.join(test_Tapes_path, file))
    # 将numpy数组转换为DataFrame
    temp_Tapes_df = pd.DataFrame(data)
    # 追加到主DataFrame
    test_Tapes_df = pd.concat([test_Tapes_df, temp_Tapes_df], ignore_index=True)

# 保存成文件
test_LOBs_df.to_csv('test_LOBs_df.csv')
test_Tapes_df.to_csv('test_Tapes_df.csv')

# %%
# 横着合并lobs和tapes
# 此时csv文件未拟合

train_df = pd.concat([train_LOBs_df,train_Tapes_df],axis=1)
train_df.to_csv('train_df.csv')

valid_df = pd.concat([valid_LOBs_df,valid_Tapes_df],axis=1)
valid_df.to_csv('valid_df.csv')

test_df = pd.concat([test_LOBs_df,test_Tapes_df],axis=1)
test_df.to_csv('test_df.csv')

# %%
# 加载df并使第0列为索引，防止自动加索引
train_df = pd.read_csv('train_df.csv', index_col=0)

train_df.shape
# Out:
# (240000, 254)

# %%
# 加载df并使第0列为索引，防止自动加索引
valid_df = pd.read_csv('valid_df.csv', index_col=0)

valid_df.shape
# Out:
# (60000, 254)

# %%
# 加载df并使第0列为索引，防止自动加索引
test_df = pd.read_csv('test_df.csv', index_col=0)

test_df.shape
# Out:
# (75000, 254)

# %%
# 加载df并使第0列为索引，防止自动加索引
test_LOBs_df = pd.read_csv('test_LOBs_df.csv', index_col=0)
test_Tapes_df = pd.read_csv('test_Tapes_df.csv', index_col=0)

valid_LOBs_df = pd.read_csv('valid_LOBs_df.csv', index_col=0)
valid_Tapes_df = pd.read_csv('valid_Tapes_df.csv', index_col=0)

train_LOBs_df = pd.read_csv('train_LOBs_df.csv', index_col=0)
train_Tapes_df = pd.read_csv('train_Tapes_df.csv', index_col=0)

# %%
# Feature scaling
scaler = MinMaxScaler()

# fit train
scaler.fit(train_df)

train_df = scaler.transform(train_df)

valid_df = scaler.transform(valid_df)

test_df = scaler.transform(test_df)

# %%
# 模型构建
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(248, 1)),
    Dropout(0.2),
    LSTM(30, return_sequences=False),
    Dense(6)  # 输出维度为6
])

# %%
# 编译优化
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# 分训练集数据
X_train = train_df[:, :248]  # 选择前248列作为X_train

y_train = train_df[:, -6:]   # 选择最后6列作为y_train

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (240000, 248)
# y_train shape: (240000, 6)

# %%
# 分验证集数据
X_valid = valid_df[:, :248]

y_valid = valid_df[:, -6:]

print("X_valid shape:", X_valid.shape)
print("y_valid shape:", y_valid.shape)
# Out:
# X_valid shape: (60000, 248)
# y_valid shape: (60000, 6)

# %%
# 分测试集数据
X_test = test_df[:, :248]

y_test = test_df[:, -6:]

print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_test shape: (75000, 248)
# y_test shape: (75000, 6)

# %%
# 初始化用于存储验证损失的列表
#val_losses = []

# 创建ModelCheckpoint实例
checkpoint_path = f"novalid_models/model-epoch{{epoch:03d}}.keras"
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,       # 检查点文件的保存路径
    monitor='loss',             # 监控的数据是loss因为验证集不可用
    save_best_only=False,           # 保存所有模型，不仅仅是最好的模型
    save_weights_only=False,         # 保存完整模型
    mode='auto',
    verbose=1)                      # 打印详细日志

# %%
# 模型训练（去掉验证集validate set）
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    callbacks=[checkpoint_callback]     # 使用checkpoint回调/每次周期保存模型
)
# Out:
# Epoch 1/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 1: saving model to novalid_models/model-epoch001.keras
# 7500/7500 [==============================] - 461s 61ms/step - loss: 0.0060
# Epoch 2/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 2: saving model to novalid_models/model-epoch002.keras
# 7500/7500 [==============================] - 465s 62ms/step - loss: 0.0052
# Epoch 3/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 3: saving model to novalid_models/model-epoch003.keras
# 7500/7500 [==============================] - 461s 62ms/step - loss: 0.0108
# Epoch 4/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 4: saving model to novalid_models/model-epoch004.keras
# 7500/7500 [==============================] - 462s 62ms/step - loss: 0.0087
# Epoch 5/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0089
# Epoch 5: saving model to novalid_models/model-epoch005.keras
# 7500/7500 [==============================] - 463s 62ms/step - loss: 0.0089
# Epoch 6/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 6: saving model to novalid_models/model-epoch006.keras
# 7500/7500 [==============================] - 461s 61ms/step - loss: 0.0082
# Epoch 7/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 7: saving model to novalid_models/model-epoch007.keras
# 7500/7500 [==============================] - 463s 62ms/step - loss: 0.0055
# Epoch 8/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 8: saving model to novalid_models/model-epoch008.keras
# 7500/7500 [==============================] - 463s 62ms/step - loss: 0.0051
# Epoch 9/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 9: saving model to novalid_models/model-epoch009.keras
# 7500/7500 [==============================] - 460s 61ms/step - loss: 0.0049
# Epoch 10/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 10: saving model to novalid_models/model-epoch010.keras
# 7500/7500 [==============================] - 464s 62ms/step - loss: 0.0067
# Epoch 11/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 11: saving model to novalid_models/model-epoch011.keras
# 7500/7500 [==============================] - 460s 61ms/step - loss: 0.0055
# Epoch 12/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 12: saving model to novalid_models/model-epoch012.keras
# 7500/7500 [==============================] - 463s 62ms/step - loss: 0.0049
# Epoch 13/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 13: saving model to novalid_models/model-epoch013.keras
# 7500/7500 [==============================] - 463s 62ms/step - loss: 0.0046
# Epoch 14/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 14: saving model to novalid_models/model-epoch014.keras
# 7500/7500 [==============================] - 460s 61ms/step - loss: 0.0044
# Epoch 15/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 15: saving model to novalid_models/model-epoch015.keras
# 7500/7500 [==============================] - 464s 62ms/step - loss: 0.0045
# Epoch 16/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0139
# Epoch 16: saving model to novalid_models/model-epoch016.keras
# 7500/7500 [==============================] - 461s 61ms/step - loss: 0.0139
# Epoch 17/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 17: saving model to novalid_models/model-epoch017.keras
# 7500/7500 [==============================] - 464s 62ms/step - loss: 0.0073
# Epoch 18/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 18: saving model to novalid_models/model-epoch018.keras
# 7500/7500 [==============================] - 464s 62ms/step - loss: 0.0068
# Epoch 19/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 19: saving model to novalid_models/model-epoch019.keras
# 7500/7500 [==============================] - 461s 61ms/step - loss: 0.0053
# Epoch 20/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 20: saving model to novalid_models/model-epoch020.keras
# 7500/7500 [==============================] - 464s 62ms/step - loss: 0.0048
# Epoch 21/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 21: saving model to novalid_models/model-epoch021.keras
# 7500/7500 [==============================] - 467s 62ms/step - loss: 0.0044
# Epoch 22/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 22: saving model to novalid_models/model-epoch022.keras
# 7500/7500 [==============================] - 472s 63ms/step - loss: 0.0041
# Epoch 23/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 23: saving model to novalid_models/model-epoch023.keras
# 7500/7500 [==============================] - 467s 62ms/step - loss: 0.0046
# Epoch 24/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 24: saving model to novalid_models/model-epoch024.keras
# 7500/7500 [==============================] - 462s 62ms/step - loss: 0.0040
# Epoch 25/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 25: saving model to novalid_models/model-epoch025.keras
# 7500/7500 [==============================] - 465s 62ms/step - loss: 0.0038
# Epoch 26/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 26: saving model to novalid_models/model-epoch026.keras
# 7500/7500 [==============================] - 465s 62ms/step - loss: 0.0050
# Epoch 27/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 27: saving model to novalid_models/model-epoch027.keras
# 7500/7500 [==============================] - 462s 62ms/step - loss: 0.0041
# Epoch 28/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 28: saving model to novalid_models/model-epoch028.keras
# 7500/7500 [==============================] - 466s 62ms/step - loss: 0.0040
# Epoch 29/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 29: saving model to novalid_models/model-epoch029.keras
# 7500/7500 [==============================] - 463s 62ms/step - loss: 0.0037
# Epoch 30/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 30: saving model to novalid_models/model-epoch030.keras
# 7500/7500 [==============================] - 467s 62ms/step - loss: 0.0035
# Epoch 31/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 31: saving model to novalid_models/model-epoch031.keras
# 7500/7500 [==============================] - 467s 62ms/step - loss: 0.0033
# Epoch 32/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 32: saving model to novalid_models/model-epoch032.keras
# 7500/7500 [==============================] - 464s 62ms/step - loss: 0.0032
# Epoch 33/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 33: saving model to novalid_models/model-epoch033.keras
# 7500/7500 [==============================] - 467s 62ms/step - loss: 0.0031
# Epoch 34/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 34: saving model to novalid_models/model-epoch034.keras
# 7500/7500 [==============================] - 466s 62ms/step - loss: 0.0036
# Epoch 35/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 35: saving model to novalid_models/model-epoch035.keras
# 7500/7500 [==============================] - 467s 62ms/step - loss: 0.0035
# Epoch 36/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 36: saving model to novalid_models/model-epoch036.keras
# 7500/7500 [==============================] - 470s 63ms/step - loss: 0.0032
# Epoch 37/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 37: saving model to novalid_models/model-epoch037.keras
# 7500/7500 [==============================] - 468s 62ms/step - loss: 0.0030
# Epoch 38/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 38: saving model to novalid_models/model-epoch038.keras
# 7500/7500 [==============================] - 507s 68ms/step - loss: 0.0029
# Epoch 39/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 39: saving model to novalid_models/model-epoch039.keras
# 7500/7500 [==============================] - 544s 73ms/step - loss: 0.0028
# Epoch 40/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 40: saving model to novalid_models/model-epoch040.keras
# 7500/7500 [==============================] - 543s 72ms/step - loss: 0.0027
# Epoch 41/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 41: saving model to novalid_models/model-epoch041.keras
# 7500/7500 [==============================] - 539s 72ms/step - loss: 0.0027
# Epoch 42/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 42: saving model to novalid_models/model-epoch042.keras
# 7500/7500 [==============================] - 546s 73ms/step - loss: 0.0026
# Epoch 43/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 43: saving model to novalid_models/model-epoch043.keras
# 7500/7500 [==============================] - 550s 73ms/step - loss: 0.0025
# Epoch 44/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 44: saving model to novalid_models/model-epoch044.keras
# 7500/7500 [==============================] - 551s 74ms/step - loss: 0.0025
# Epoch 45/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 45: saving model to novalid_models/model-epoch045.keras
# 7500/7500 [==============================] - 490s 65ms/step - loss: 0.0027
# Epoch 46/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 46: saving model to novalid_models/model-epoch046.keras
# 7500/7500 [==============================] - 476s 64ms/step - loss: 0.0025
# Epoch 47/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 47: saving model to novalid_models/model-epoch047.keras
# 7500/7500 [==============================] - 470s 63ms/step - loss: 0.0024
# Epoch 48/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 48: saving model to novalid_models/model-epoch048.keras
# 7500/7500 [==============================] - 472s 63ms/step - loss: 0.0052
# Epoch 49/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0107
# Epoch 49: saving model to novalid_models/model-epoch049.keras
# 7500/7500 [==============================] - 472s 63ms/step - loss: 0.0107
# Epoch 50/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.0179
# Epoch 50: saving model to novalid_models/model-epoch050.keras
# 7500/7500 [==============================] - 468s 62ms/step - loss: 0.0179

# %%
# 提取并存储每个周期的损失
losses = history.history['loss']

# 在所有训练完成后，将loss保存到CSV文件
loss_df = pd.DataFrame(losses, columns=['loss'])
loss_df.to_csv('losses.csv', index_label='epoch')
print(f"losses saved.")
# Out:
# losses saved.

# %%
# 可视化val_loss，选出最好的模型

loss_df = pd.read_csv('losses.csv', index_col=0)

epoch = loss_df.index  

loss = loss_df['loss']

# 创建图表
plt.figure(figsize=(10, 5))

# 绘制验证损失
plt.plot(epoch, loss, label='Loss', color='yellowgreen', marker='o')

# 添加标题和图例
plt.title('Loss During Training')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.savefig('Loss During Training.png')

# 显示图表
plt.show()

# %%
# 加载最优模型
model_path = 'novalid_models/model-epoch047.keras'
model = load_model(model_path)

# %%
# 新数据点预测
y_pred = model.predict(X_test)
# Out:
# 2344/2344 [==============================] - 52s 22ms/step

# %%
# 模型评估
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("Mean Squared Error on Test Set:", mse)
print("Root Mean Squared Error on Test Set:", rmse)
# Out:
# Mean Squared Error on Test Set: 0.03855019376991605
# Root Mean Squared Error on Test Set: 0.1963420326112472

# %%
# 横向合并 X_test和 y_pred（为了之后rescale）
combined_pred = np.hstack((X_test, y_pred))

# %%
# rescale
combined_pred_rescaled = scaler.inverse_transform(combined_pred)

# %%
# 提取最后6列为rescale后的预测值
y_pred_value = combined_pred_rescaled[:, -6:]

# 将 y_pred_value 转换为一维数组
y_pred_value_flatten = y_pred_value.flatten()

# 将 y_pred_value 转换为 DataFrame 并保存
pd.DataFrame(y_pred_value_flatten).to_csv('y_pred_value_flatten.csv')

# 打印预测值
print("Flatten Predicted Values:", y_pred_value_flatten)
# Out:
# Flatten Predicted Values: [152.21272707 152.01270834 152.24507529 ... 159.25860316 159.42345491
#  159.54307491]

# %%
# y_true_value 

y_true_value = test_Tapes_df

print(y_true_value)
# Out:
#                 0       1           2           3           4      5
# 0      111.600000  111.30  111.000000  111.000000  111.000000  109.8
# 1      111.000000  111.00  112.000000  112.000000  112.000000  111.5
# 2      111.000000  109.00  108.666667  109.666667  110.666667  108.0
# 3      107.666667  107.00  106.000000  105.000000  106.000000  106.0
# 4      110.500000  109.00  109.000000  110.000000  111.000000  110.2
# ...           ...     ...         ...         ...         ...    ...
# 74995  105.000000  106.25  107.500000  108.750000  110.000000  109.0
# 74996  110.000000  107.75  112.000000  111.250000  109.000000  106.0
# 74997  107.400000  106.00  105.200000  103.500000  103.000000  105.0
# 74998  112.000000  108.00  112.000000  111.000000  109.000000  109.0
# 74999  109.000000  109.00  107.250000  108.000000  108.000000  107.5
#
# [75000 rows x 6 columns]

# %%
# 将 DataFrame 转换为一维数组
y_true_value_flattened = y_true_value.values.flatten()

# 打印一维数组
print("Flattened True Values:", y_true_value_flattened)
# Out:
# Flattened True Values: [111.6 111.3 111.  ... 108.  108.  107.5]

# %%
# 可视化预测结果与真实数据

# 100-200个点

plt.figure(figsize=(10, 5))
plt.plot(y_true_value_flattened , label='Actual Weighted Price', color='royalblue', linewidth=0.4)
plt.plot(y_pred_value_flatten, label='Predicted Weighted Price', color='darkorange', linewidth=0.4)
plt.title(f'Prediction Set Prediction vs True Data from novalid model')
plt.xlabel('Time Steps')
plt.ylabel('Weighted Price')
plt.legend()
plt.grid(True)

# 保存图像
plt.savefig('Pred_Predicted_vs_Actual_Weighted_Price.png')

plt.show()

# %%
# 验证集预测对照
# 加载最优模型
model_path = 'novalid_models/model-epoch046.keras'

model = load_model(model_path)

y_valid_pred = model.predict(X_valid)

# 模型评估
mse_valid = mean_squared_error(y_valid, y_valid_pred)
rmse_valid = np.sqrt(mse_valid)

print("Mean Squared Error on Test Set:", mse_valid)
print("Root Mean Squared Error on Test Set:", rmse_valid)

# 横向合并 X_test和 y_pred（为了之后rescale）
combined_valid_pred = np.hstack((X_valid, y_valid_pred))

# rescale
combined_valid_pred_rescaled = scaler.inverse_transform(combined_valid_pred)

# 提取最后6列为rescale后的预测值
y_valid_pred_value = combined_valid_pred_rescaled[:, -6:]

# 将 y_pred_value 转换为一维数组
y_valid_pred_value_flatten = y_valid_pred_value.flatten()

# 将 y_pred_value 转换为 DataFrame 并保存
#pd.DataFrame(y_valid_pred_value_flatten).to_csv('y_valid_pred_value_flatten.csv')

# 打印预测值
#print("Flatten Predicted Values:", y_valid_pred_value_flatten)

# y_true_value 

y_valid_true_value = valid_Tapes_df

#print(y_valid_true_value)

# 将 DataFrame 转换为一维数组
y_valid_true_value_flattened = y_valid_true_value.values.flatten()

# 打印一维数组
#print("Flattened True Values:", y_valid_true_value_flattened)

# 可视化预测结果与真实数据

# 100-200个点
# Out:
# 1875/1875 [==============================] - 42s 22ms/step
# Mean Squared Error on Test Set: 0.00245935065152527
# Root Mean Squared Error on Test Set: 0.04959184057408305

# %%
plt.figure(figsize=(10, 5))
plt.plot(y_valid_true_value_flattened , label='Actual Weighted Price', color='steelblue', linewidth=0.4)
plt.plot(y_valid_pred_value_flatten, label='Predicted Weighted Price', color='salmon', linewidth=0.4)
plt.title(f'Validation Set Prediction vs True Data from novalid model')
plt.xlabel('Time Steps')
plt.ylabel('Weighted Price')
plt.legend()
plt.grid(True)

# 保存图像
plt.savefig('Valid_Predicted_vs_Actual_Weighted_Price.png')

plt.show()
